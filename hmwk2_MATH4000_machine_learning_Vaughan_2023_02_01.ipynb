# %% [markdown]
# #  David Vaughan  R1166390
# # (MATH-4000-004)
# # Homework 2 Due Feb 1 2023
# #  Spring 2023 TTU Selected Topics: Machine learning model order reduction for differential equations (MATH-4000-004) Full Term: Homework for week 2

# %% [markdown]
# ## Homework submission format
# 1. For problem 1 and 2, please submit the answers in PDF format (you can scan the handwritten paper or use LaTeX).
# 2. For problem 3, 4 and 5, please submit the code in Jupyter Notebook format.

# %% [markdown]
# ### Problem 1
# ### PDF handwritten or LaTx
# Compute the Hessian matrix of $L(m,b)$ on page 3 of lecture note and prove it is positive definite.

# %% [markdown]
# ### Problem 2
# ### PDF handwritten or LaTx
# For the generalization of linear regession problem
# 1. Compute $\frac{\partial L}{\partial m_1}$, $\frac{\partial L}{\partial m_2}$ and $\frac{\partial L}{\partial b}$.
# 2. Find out the values of $m_1$, $m_2$ and $b$ by solving the equations $\frac{\partial L}{\partial m_1}=0$, $\frac{\partial L}{\partial m_2}=0$ and $\frac{\partial L}{\partial b}=0$.
# 3. Compute the Hessian matrix of $L(m_1, m_2, b)$ and prove it is positive definite.

# %% [markdown]
# ### Problem 3
# For the generalization of linear regession problem
# 1. Use the result from Problem 2 to compute $m_1$, $m_2$ and $b$ for the following dataset.
# 2. Plot the linear function and compare with the dataset. (Hint: the linear function depends on two variables $x_1$ and $x_2$, so you should plot it in 3D coordinates. You may follow the example here https://matplotlib.org/stable/gallery/mplot3d/surface3d.html)

# %%
# Example from Matplot lib
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# GIVEN 
import numpy as np

N = 20
x1 = np.random.rand(N)
x2 = np.random.rand(N)
y = 2*x1 + 3*x2 + 1 + np.random.rand(N) * 0.2

# %%
# my code
###
# 
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

def prob3():
    
    # GIVEN 
    N = 20
    #N = 200
    # it does not like n = 20000
    x1 = np.random.rand(N)
   # print(x1)
    x2 = np.random.rand(N)
   # print(x2)
    # maybe meshgrid?
    x1, x2 = np.meshgrid(x1, x2)
   
    y = 2*x1 + 3*x2 + 1 + np.random.rand(N) * 0.2
    # print(y)
    #given

    #m1 = (qt + rs)/((ps − qu))
    q = N*np.sum(x2*x1)-(np.sum(x2)*np.sum(x1))
    t =(np.sum(y)*np.sum(x2))-N*np.sum(y*x2)
    r = (np.sum(y)*np.sum(x1))-N*np.sum(y*x1)
    s = -N*np.sum(x2*x2)+(np.sum(x2)*np.sum(x2))
    p = -N*np.sum(x1*x1)+(np.sum(x1)*np.sum(x1))
    u = N*np.sum(x2*x1)-(np.sum(x1)*np.sum(x2))

    m1 = ( (q*t)+(r*s) )/((p*s) - (q*u))
    # m2 = (N*m1*np.sum(x2*x1)-m1(np.sum(x1)*np.sum(x2))+(np.sum(y)*np.sum(x2)))/(-N*np.sum(x2*x2)+(np.sum(x2)*np.sum(x2)))
    m2 = (m1*(u)+t)/s
    b =(-m1*np.sum(x1)-m2*np.sum(x2)+np.sum(y))/N
    # print(m1,m2, b)
    #LATER
    # GRAPH PART
    fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
    # meshgrid Return coordinate matrices from coordinate vectors.
    # NEcessary?
    # x1, x2 = np.meshgrid(x1, x2)
    
    # print(x1,x2)
    # print(x2)
    # Plot the surface.
    surf = ax.plot_surface(x1, x2, y, cmap=cm.Spectral,
                          linewidth=0, antialiased=False)
    # Graph look close to orginal graph I guess
    surf2 = ax.plot_surface(x1, x2, (m1*x1+m2*x2)+b, cmap=cm.coolwarm,
                           linewidth=0, antialiased=False)

    # Customize the z axis.
    #ax.set_zlim(-1.01, 1.01)
    #ax.zaxis.set_major_locator(LinearLocator(10))
    # A StrMethodFormatter is used automatically
    ax.zaxis.set_major_formatter('{x:.02f}')

    # Add a color bar which maps values to colors.
    fig.colorbar(surf, shrink=0.5, aspect=5)
    fig.colorbar(surf2, shrink=0.5, aspect=5)
    
    plt.show()

# %%
prob3()

# %% [markdown]
# ### Answer to Problem 3

# %% [markdown]
# ### Problem 4
# Follow the example code in activation function given in lecture-01-code.ipynb
# 1. Plot the ReLU function.
# 2. Plot the Tanh function.

# %%
# my code
###
# 
import matplotlib.pyplot as plt
import numpy as np
# ReLU function.
def prob4R():
    # x is a array with 100 numbers between -10 and 10
    x = np.linspace(-10, 10, 100)
   # numbers=np.where((numbers%4==0) | (numbers%7==0), numbers*10, numbers/10)
#could use max instead
# if x[number] <0 then y =0 else y = [x]
    y = np.where((x<0),0,x)
    plt.figure()
    plt.plot(x,y)

# %%
prob4R()

# %%
# my code
###
# 
import matplotlib.pyplot as plt
import numpy as np
# Tanh function.
def prob4T():
    # x is a array with 100 numbers between -10 and 10
    x = np.linspace(-10, 10, 100)
    y = np.tanh(x)
    plt.figure()
    plt.plot(x,y)

# %%
prob4T()

# %% [markdown]
# ### Answer to Problem 4
# done

# %%
# EXAMPLE FROM LECTURE
import matplotlib.pyplot as plt
import numpy as np

# sigmoid function
x = np.linspace(-10, 10, 100)
y = 1/(1+np.exp(-x))

plt.figure()
plt.plot(x,y)

# %% [markdown]
# ### Problem 5
# 1. How difficult do you think of this homework? Please give your marks between 1-5 (1 is the easiest and 5 is the most difficult).
# 2. How difficult do you think of this lecture? Please give your marks between 1-5 (1 is the easiest and 5 is the most difficult).
#
# I will try to adjust the lecture and homework based on your feedback.

# %% [markdown]
# ### Answer to Problem 5
# <br> difficultly for problems 3-5 ;         1.
# <br> difficultly for problems 2a,2b ;       2.5.
#  <br> difficultly for problems 1 and 2c ;    4.
#  <br> lecture 2 difficultly 1.5
#  <br> I know objectively 1 and 2c are not that hard, but it just felt really hard.
#  <br>  For problem 1 and 2c Finding the positive defenite of a matrix with Sumations was difficult, I do not know that I did it right.
#  <br> (sumation x^2  sumation x  ,sumation x  n) I assume that you cannot know that the determiant is greater than 0,so that you
# find a *M *a transpose>0 by useing derivative test.
# <br>  It seems Finding the positive defenite of a simple matrix like (1 2, 3 8) would be easy.det 1, det (8 -6) = 2 1,2 minors >0. or eigenvalues>0 (could use quadratic formula), or a *M *a transpose>0 , a is non-zero vector  like(a,b,c) M transpose of (a,b,c), complete square.
# <br> M is congruent with a diagonal matrix with positive real entries. or There exists an invertible matrix B B with conjugate transpose B ∗ { B^{*}} such that M = B ∗ B . { M=B^{*}B.} seem like it be hard to calculate

# %%
# my code
### WHY PYTHON
# FIX LATER
import matplotlib.pyplot as plt
import numpy as np
# ReLU function.
def prob4p():
    x = np.linspace(-10, 10, 100)
    y = []
    for i in range(len(x)-1):
        
        if(x[i]<0):
            y = y.append(0)
        else:
            y = y.append(x[i])
    plt.figure()
    plt.plot(x,y)

# %%
# prob4p()
